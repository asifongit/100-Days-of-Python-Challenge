# %% [markdown]
# Write a program that will convert celsius value to fahrenheit

# %% [markdown]
# Fahrenheit = (Celsius × 1.8) + 32

# %% [markdown]
# One way of Coding

# %%
Celsius=int(input("Enter the Celcius Value: "))
calculate=(Celsius*1.8)+32
print(calculate)
# Out:
# 73.4

# %% [markdown]
# Second way of coding

# %%
#Define a function
def calcualate_Fahrenheit(Celsius):
    return (Celsius*1.8)+32

#Call a function and pass a value inside a function
calcualate_Fahrenheit(23)
# Out:
# 73.4
