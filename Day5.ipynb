# %% [markdown]
# Write a program that will reverse a four digit number.Also it checks
# whether the reverse is true.

# %%
a=[2,3,4,5]
a.reverse()
print(a)
if a==[5,4,3,2]:
    print("Success")
# Out:
# [5, 4, 3, 2]
# Success

# %%
list=[]
a=int(input('enter the first no'))
b=int(input('Enter the second no'))
list.append(a)
list.append(b)

list.reverse()
print(list)


if list[0]==b and list[1]==a:
    print('True')
# Out:
# [34, 23]
# True
