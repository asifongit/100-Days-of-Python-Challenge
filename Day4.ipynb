# %% [markdown]
# Write a program that will give you the sum of 3 digits

# %%
a=4
b=9
c=7
sum=a+b+c
print(sum)
# Out:
# 20

# %%
def sum_of_digit():
    a=4
    b=5
    c=9
    sum=a+b+c
    return sum

sum_of_digit()
# Out:
# 18
